# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import IPython.display as ipd
from scipy.io import wavfile
from scipy import signal
from scipy.signal import firwin, remez, kaiser_atten, kaiser_beta

# %%
a1 = 1
a2 = 3

# %%
t = np.arange (0,5,0.0001)

# %%
x = 1.5*np.sin(2*np.pi*a1*t) - 3*np.sin(2*np.pi*a2*t) + 2*np.sin(2*np.pi*(a1+a2)*t)

# %%
plt.figure(figsize=(15,3))
plt.plot(t,x)
plt.show()

# %%
fs = 24
n = np.arange (0,5,1/fs)

# %%
sig_amost = 1.5*np.sin(2*np.pi*a1*n) - 3*np.sin(2*np.pi*a2*n) + 2*np.sin(2*np.pi*(a1+a2)*n)

# %%
plt.figure(figsize=(15,3))

plt.plot(t,x)

plt.stem(n,sig_amost,"r")
plt.show()

# %%
x1_fourier = np.fft.fft(sig_amost)
x1_fourierfreq = np.fft.fftfreq(len(sig_amost), 1/(2*np.pi)) #frequencias no dominio DISCRETO

# %%
plt.figure(figsize=(15,3))
plt.plot(x1_fourierfreq, abs(x1_fourier))
plt.xlim()
plt.ylim()
plt.show()

# %%
beta = 12.0
ntaps = 3

freq = [0.0, 12]
gain = [0, 1.0]

lowcut = 0
highcut = fs/2

# %%
signal.firwin2(ntaps,freq,gain,8, window='triangle')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-201-d21b50f7b642> in <module>()
# ----> 1 signal.firwin2(ntaps,freq,gain,8, window='triangle')
#
# ~\Anaconda3\lib\site-packages\scipy\signal\fir_filter_design.py in firwin2(numtaps, freq, gain, nfreqs, window, nyq, antisymmetric, fs)
#     566
#     567     if freq[0] != 0 or freq[-1] != nyq:
# --> 568         raise ValueError('freq must start with 0 and end with fs/2.')
#     569     d = np.diff(freq)
#     570     if (d < 0).any():
#
# ValueError: freq must start with 0 and end with fs/2.
